# %%
#pip install google

# %%
#pip install google-cloud

# %%
#pip install google-cloud-vision

# %%
import urllib
import requests
import time
import sys
import datetime
import csv
import os
import re
from bs4 import BeautifulSoup
import google
import ssl
from urllib.request import urlopen
import urllib.parse
from urllib.request import urlretrieve
from urllib.parse import quote
import json

# %%
context = context = ssl._create_unverified_context()

api_key = ''

#google_places = Google(MY_API_KEY)

OutBN = " "
OutAdd  = " "
OutCity = " "
OutProv = " "
OutPost = " "
OutLat  = " "
OutLng  = " "
OutRtg  = " "
OutTyp  = " "

# %%
def getCategories(lCat):
    global id 
    cid = ""
    cID = 0  
    if "category" in a['href']:  
        urlCID = "http://mystore411.com" + str(a['href'])
        start = urlCID.find("category/") + 9
        cid = urlCID[start:]        
        id += 10
        iid = "%03d" % (id)
        urlCID = urlCID + "/cid=" + str(iid)
        lCat.append(urlCID)
    return lCat, id, cid

# %%
def getBizNew(url):
    lBiz =[]
    bizID = ""
    bizDesc = ""
    
    end = url.find('/cid=', 0)
    newURL = url[0: end]    

    store = urlopen(newURL,context = context)   
    cat_soup = BeautifulSoup(store, "lxml") 
    
    start = url.find('/cid=') + 5 ## CAT_ID
    cid = url[start:]
    

    start = url.find('/cid=') + 5 ## CAT_ID
    cid = url[start:]  
    

    BizList = str(cat_soup.find_all("a", href=True)).split(",")
    
    for i in range(0,len(BizList)):
        if re.search(r"/store/listing", BizList[i]):
            start = BizList[i].find('listing/') + 8
            end = BizList[i].find('\">')
            urlR = quote(BizList[i][start:end])
            url = "https://www.mystore411.com/store/listing/" + urlR
            
            
            store = urlopen(url,context = context)   
            store_soup = BeautifulSoup(store, "lxml") 
            
            StoreList = str(store_soup.find_all("a", href=True)).split(",")
            
            for j in range (0, len(StoreList)):
                if re.search(r"/store/listing", StoreList[j]):
                    if re.search(r'/Canada/', StoreList[j]):
                
                        start = StoreList[j].find('listing/') + 8
                        end = StoreList[j].find('-store', start)
                        biz = quote(StoreList[j][start:end])
                                
                        #url = quote(("https://www.mystore411.com/store/listing/" + biz + "-store-locations"), encoding='utf8')
                        url = "https://www.mystore411.com/store/listing/" + biz + "-store-locations"
                        
                        lBiz.append(url)
                    
                        start = url.find('store/listing/') + 14 ## BIZ_ID
                        end = url.find('/Canada/', start)
                        bizID = url[start:end]
                        
                        start = url.find('/Canada/') + 8  ## BIZ_DESC
                        end = url.find('-store', start)
                        bizDesc = url[start:end]
            
                        iibizID  = "%05d" % (int(bizID))
                        with open('BZC.csv', 'a') as csvfile:
                            fieldnames = ['BIZ_ID', 'BIZ_DESC', 'CAT_ID']
                            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
                            writer.writerow({'BIZ_ID': iibizID, 'BIZ_DESC': bizDesc, 'CAT_ID':cid})  
    return lBiz

# %%
def getCities(url):
    lCity = []
    store = urlopen(url,context = context)
    time.sleep(2) ## This delay is necessary otherwise the program crashes!!
    soup = BeautifulSoup(store, "lxml") 
    if soup.find("th", colspan="3"): ## this means there are Cities in the Province
        CityList = str(soup.find_all("a", href=True)).split(",")
        for i in range(0,len(CityList)):
            if "/Canada/" in CityList[i]: ## important need to look for Canada/ because Canada is sometime embedded in name
                if "/list_city/" in CityList[i]:
                    start = CityList[i].find('list_city/') + 10 ## strings start in [0] in python!
                    end = CityList[i].find('-store', start)
                    City = CityList[i][start:end]
                    url = "https://www.mystore411.com/store/list_city/" + City + "-store-locations"
                    #url = urllib.parse.quote(("https://www.mystore411.com/store/list_city/" + City + "-store-locations"), encoding='utf8') 
                    lCity.append(url)
    else:
        TGetLocation(url)
    return lCity

# %%
def getAddress(storeURL):
    global OutAdd  
    global OutCity
    global OutProv
    global OutPost
    
    store = urlopen(storeURL,context = context)
    #store = storeURL.read()

    soup = BeautifulSoup(store, "lxml") ## this is wrong, not suppose to re-read!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    
    
    ##print(storeURL)
    ## conforming address
    span = str(soup.find_all("span",itemprop="streetAddress"))
    ##print "debugging span=", span
    start = span.find('Address') + 9
    end = span.find('<br', start)
    address = str(span[start:end]) + "" ## I am converting to string if I can get rid of ""
    ## addressLocality
    span = str(soup.find_all("span",itemprop="addressLocality")) ## City
    start = span.find("Locality") + 10
    end = span.find('</span>', start)
    loc = span[start:end]
    ## addressRegion
    span = str(soup.find_all("span",itemprop="addressRegion")) ## Province
    start = span.find("Region") + 8
    end = span.find('</span>', start)
    reg = span[start:end]
    ## postalCode
    span = str(soup.find_all("span",itemprop="postalCode"))
    start = span.find("Code") + 6
    end = span.find('</span>', start)
    pos = span[start:end]
        
    add = address + " " + loc + " " + reg + " " + pos
    
    ## conform table
    OutAdd  = address
    print ("at getAddress ====== address is>", address, "<")
    
    OutCity = loc
    OutProv = reg
    OutPost = pos
    
    return add, address, loc, reg, pos

# %%
# In[ ]:
def getGeoloc(add, data_type='json'):
    ##
    ## get coordinates of address
    time.sleep(2)
    param = {'address': add, 'key': 'api_key'} ## here used Google API
    geo_s = 'https://maps.googleapis.com/maps/api/geocode/json' ## needed
    response = requests.get(geo_s, params=param)
    json_dict = response.json()
    if response.status_code not in range(200, 299):
        return {}
    latlng = {}
    try:
        latlng = json_dict['results'][0]['geometry']['location']
    except:
        pass
      
    return latlng.get('lat'), latlng.get('lng')











#def getGeoloc(add):
    ####
    #### get coordinates of address
    #time.sleep(2)
    #param = {'address': add, 'key': 'api_key'} ## here used Google API
    #geo_s = 'https://maps.googleapis.com/maps/api/geocode/json' ## needed
    
    #try:
        #response = requests.get(geo_s, params=param)
        #json_dict = response.json()
        #lat = json_dict['results'][0]['geometry']['location']['lat']
        #lng = json_dict['results'][0]['geometry']['location']['lng']      
    #except:
        #print ("*** ERROR at getGeoloc, unable to retrieve lat and lng ***")
      
    #return str(lat), str(lng)

# %%
# In[ ]:


def unlistTypes(types):
## remove unwanted characters from types
    l = str(types)
    s = l
    l = s
    rc = "[u\']"
    for i in range(0, len(rc)):
        if rc[i] in l:
            s = s.replace(rc[i],"")
        
    return s

# %%
# In[ ]:


def getStates(url):
    print("******************* in getStates def for URL:", url)
    lStates = []
    store = urlopen(url, context = context)
    from bs4 import BeautifulSoup
    soup = BeautifulSoup(store, "lxml")

    if soup.find("th", colspan="4"):
        
        ProvList = str(soup.find_all("a", href=True)).split(",")
        for i in range(0,len(ProvList)): ## decomment for production !!!
        ## for i in range(0,3): ## and I am risking that buz-cat has at least 3 locations!!!!
            if "/Canada/" in ProvList[i]: ## needs to be "Canada/" otherwise it mixes up with Canada-Goose-store-locations!!
                if "list_state" in ProvList[i]:

                    start = ProvList[i].find('list_state/') + 11 ## strings start in [0] in python!
                    end = ProvList[i].find('-store', start)
                    prov = quote(ProvList[i][start:end])
            
                    #url = quote("https://www.mystore411.com/store/list_state/" + prov + "-store-locations")
                    url = "https://www.mystore411.com/store/list_state/" + prov + "-store-locations"
                    #url = urllib.parse.quote(("https://www.mystore411.com/store/list_city/" + City + "-store-locations"), encoding='utf8') 
            
                    print("url of biz found is:", url)
            
                    lStates.append(url) ## will append only if the biz has states!
                
                    ## print("+++++++++++++++++++++++++after appending to lStates:", lStates)
                    
                    ## Here I might continue processing list_state but better I do itthrough the list
                
    else:
        ## Given that url is already filtered out for Canada I think is correct!!!
        ## read location
        print("************** THERE is NO COLSPAN=4 for ", url, "*****************************")
        print("************** I will GetLocation (url) ***************************************")
        TGetLocation(url)

    return lStates

# %%
# In[ ]:



def TGetLocation(url):
    print("at TGetLocation with url:", url)    
    ##time.sleep(2) ####################### added to hopefully avoid program stops abruptly
    
    OutBN = " "
    OutAdd  = " "
    OutCity = " "
    OutProv = " "
    OutPost = " "
    OutLat  = " "
    OutLng  = " "
    OutRtg  = " "
    OutTyp  = " "
    
    global countw
    
    ##try:
    time.sleep(5) ## introducing a delay to see if makes a difference! ## raised to 5 as per Winston
    #f = urllib.parse.quote((url), context=context)
    f = urlopen(url, context=context)
    store=f.read()
    #store = (f.decode('UTF-8')).read()
    #json_obj = json.loads(store)
    #store = f.read()
    #print(f.read(100).decode('utf-8'))
    
    print("AFTER READING URL. url for top biz is", url)
   
    from bs4 import BeautifulSoup
    soup = BeautifulSoup(store, "lxml")
    
    print("at TgetLocation ====== url for top biz is", url) 

    counter = 0
    for a in soup.find_all('a',href=True): 
        ## print("in for a[href] ======", a['href'])
        if "view" in a['href']:
            counter+=1 ## delete after testing!!!
            print("a[href] with (view) ====>>>>>>>", a['href'])
            print("counter = ", counter)
            storeURL = ('https://mystore411.com' + quote(a['href']))#.encode('utf-8')
            #storeURL = urllib.parse.quote(('https://mystore411.com' + a['href']), encoding='utf8') ## Here I conform the URL for reading the store name of the biz
            #storeURL = urllib.parse.quote('https://mystore411.com' + (a['href'])))
            print("BEFORE ====== storeURL is:", storeURL, "a[href] is:", a['href'])
            if counter >= 1: ## delete for production!! just writing 1 for TESTING!!!! ##########################################
                storeURL = ('https://mystore411.com' + quote(a['href']))#.encode('utf-8') ## Here I conform the URL for reading the store name of the biz
                #print("at TGetLocation ====== storeURL is:", storeURL, "a[href] is:", a['href'])
                
                add, OutAdd, OutCity, OutProv, OutPost = getAddress(storeURL)
                
                print("*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv=", OutProv)
                
                print("The address of the biz is:", OutAdd + " " + OutCity + " " + OutProv + " " + OutPost)
            
                ##ll = getGeoloc(add).encode('ascii', 'ignore') ## 5625 Boul. M\xe9tropolitain St-L\xe9onard Quebec H1P 1X3  This may not be working
                
                lat, lng = getGeoloc(add) ## Query Google API
                
                
                print("lat and long are:", lat, " ", lng)
                
                OutLat = lat
                OutLng = lng
                
                ##pos = "pos"
                
                ## Store ID
                start = storeURL.find('/view/') + 6
                end = storeURL.find('/Canada/')
                OutSid = storeURL[start:end]
                ## here you need to extract the bizname
                
                start = url.find("Canada/") + 7
                end = url.find('-store', start) ## needs to be between Canada/ and -store!!
                bizN = url[start:end]
                
                try:
                    query_result = google_places.nearby_search(lat_lng = {'lat': lat, 'lng': lng}, name = bizN) ## Need to get the store name!
                    print ("AFTER parameters for calling google_places are lat, lng, pos =", lat, lng, bizN)
                    time.sleep(5) ## think a delay is necessary otherwise may crash!! ###########################################
                
                    place_id = query_result.places[0].place_id ## gets the place id 
                    print ("place_id=", place_id)
                
                    ## gets rating given a place_id

                    store = google_places.get_place(place_id) ## gets the rating given the place id

                    print("Store rating of", str(store.name), "is=", store.rating)
                    ##time.sleep(2) ## think a delay is necessary otherwise may crash!! ###########################################
                
                    ## conform table (within scope of if for testing)
                
                    OutBN = str(store.name) 
                    OutRtg = str(store.rating) ## needs to be str
                    
                 
                    OutTyp = unlistTypes(store.types)  ## needs to be str  

                ############ END Google Query
                                
                    ## here I include the code to gather the columns we need to conform our table
                              
                    print("===============================")
                    print ("Name=", OutBN)
                    print ("add=",  OutAdd)
                    print ("City=", OutCity) 
                    print ("Prov=", OutProv) 
                    print ("Post=", OutPost) 
                    print ("Lat=",  OutLat) 
                    print ("Lng=",  OutLng)  
                    print ("Rtg=",  OutRtg)  
                    print ("Typ=",  OutTyp) 
                    print("===============================")
                
                    ## STORE_ID
                    start = storeURL.find('/view/') + 6
                    end = storeURL.find('/Canada/')
                    OutSid = storeURL[start:end]
                
                    ## STORE_NAME
                    start = storeURL.find('/Canada/') + 8
                
                    OutSna = storeURL[start:]   
                
                    ## STORE_NAME_API
                    ## need to query API
                    OutSnw = "GOOGLE API"
                
                    ##BIZ_ID
                    ## here I need to sequentially read BZC.csv and find the BIZ_ID
                    OutBid = 12345 ## str??
                                
                    ##PROV_ID
                
                    ##CITY_ID     
                
                    ## rest of fields already recovered
                
                    with open('SL.csv', 'a') as csvfile:
                        fieldnames = ['STORE_ID', 'STORE_NAME_WEB', 'STORE_NAME_API', 
                                      'BIZ_ID', 'PROV_ID', 'CITY_ID', 'ADDRESS', 
                                      'POSTAL_CODE', "LATITUDE", "LONGITUDE", 
                                      'RATING', 'TYPES']
                        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
                        ##########################################################################################
                        writer.writerow({'STORE_ID': OutSid, 'STORE_NAME_WEB': OutSnw,"STORE_NAME_API": OutSna, 
                                         'BIZ_ID': OutBid, "PROV_ID": OutProv, 'CITY_ID':OutCity, 'ADDRESS':OutAdd,
                                         "POSTAL_CODE": OutPost, "LATITUDE": OutLat,"LONGITUDE": OutLng, 
                                         "RATING": OutRtg, "TYPES": OutTyp})
                        ##########################################################################################    
                
                        ##countw+=1
                        ##print("Im writing #", countw)              
                
                
                    with open('SAMPLE.csv', 'a') as csvfile:
                        fieldnames = ['Store_id', 'Store_Name', 'Biz_Name', 'Address', "City", 
                                      'Province', 'Postal Code','Latitude', 'Longitude', 'Rating', 'Types']

                        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
                        ##################################################################################
                        writer.writerow({'Store_id': OutSid, 'Store_Name':OutSna, 'Biz_Name': OutBN, 
                                         'Address': OutAdd, 'City': OutCity, 'Province': OutProv, 
                                         'Postal Code': OutPost, 'Latitude': OutLat, 'Longitude': OutLng, 
                                         'Rating': OutRtg, 'Types': OutTyp})
                        ##################################################################################    
                        print("Im writing #", countw)
                        countw+=1
                    
                        if countw >= 1000:
                            ## set to 10 just for testing!!
                            print("*********  EXECUTION OF PROGRAM TERMINATED **** countw =", countw)
                            exit()
                            print("********* AFTER EXIT() *******")
                            ## return 
                except:
                    print ("********* ERROR when trying to get the place_id Google API didn't like it! **********")                   
    return

# %%
# In[ ]:


def writeOutputfh():
    OUT = "./SAMPLE.csv"
    if os.path.exists(OUT):
        os.remove(OUT)
        print ("***", OUT, " file DELETED ***")
    else:
        print("The file", OUT, " does not exist")

    with open(OUT, 'a') as csvfile:
        fieldnames = ['Store_id', 'Store_Name', 'Biz_Name', 'Address', "City", 
                      'Province', 'Postal Code','Latitude', 'Longitude', 'Rating', 'Types']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

# %%
# In[ ]:


def writeCidfh():
    CID = "./CID.csv"
    if os.path.exists(CID):
        os.remove(CID)
        print ("*** ", CID, " file DELETED ***")
    else:
        print("The file ", CID, " does not exist")

    with open(CID, 'a') as csvfile:
        fieldnames = ['CAT_ID', 'CAT_DESC']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

# %%
# In[ ]:


def writeBizCfh():
    BZC = "./BZC.csv"
    if os.path.exists(BZC):
        os.remove(BZC)
        print ("*** ", BZC, " file DELETED ***")
    else:
        print("The file", BZC, " does not exist")

    with open(BZC, 'a') as csvfile:
        fieldnames = ['BIZ_ID', 'BIZ_DESC', 'CAT_ID']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

# %%
 #In[ ]:


def writeStoLfh():
    SL = "./SL.csv"
    if os.path.exists(SL):
        os.remove(SL)
        print ("*** ", SL, " file DELETED ***")
    else:
        print("The file", SL, " does not exist")

    with open(SL, 'a') as csvfile:
        fieldnames = ['STORE_ID', 'STORE_NAME_WEB', 
                      'STORE_NAME_API', 'BIZ_ID', 'PROV_ID', 
                      'CITY_ID', 'ADDRESS', 'POSTAL_CODE', 
                      "LATITUDE", "LONGITUDE", 'RATING', 'TYPES']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

# %%
url = "https://mystore411.com"

lCat   = []

id = 10

cid    = "" ## Category id only
lBiz   = []
lSta   = []
lCit   = []
lABiz  = []
lASta  = [] 
lACit  = []

##f = open("./fscraper-OUTPUT", "w") ## ???


writeOutputfh()
###############

print("top url is", url)
print ("Process of scraping website STARTS at:", datetime.datetime.now())

store = urlopen(url,context = context)
from bs4 import BeautifulSoup
soup = BeautifulSoup(store, "lxml")

writeCidfh()
############
id = 0
for a in soup.find_all('a',href=True): ## LOOK FOR ALL CATEGORIES 
    
    lCat, x, cid = getCategories(lCat)
    print("############# id antes de +10:", id)
    

    x = int(x)
    x = "%03d" % (x)
    
    ###x = x + 10
    
    print ("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x=", x, "==")
    
    ##cID = "%03d" % (id)
        
    print ("######### id after +10:", id)

    if cid:
  
        with open('CID.csv', 'a') as csvfile:
            fieldnames = ['CAT_ID', 'CAT_DESC']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            ###########################################################
            writer.writerow({'CAT_ID': x, 'CAT_DESC': cid})  
            ###########################################################  

writeBizCfh()
#############

## print("&&&&&&&&&&&&&& This is the list of categories:", lCat)
print("lABiz is", lABiz)

for i in range(0, len(lCat)):
    lBiz = getBizNew(lCat[i]) ## This f is not returning lBiz!!
    ##print "######################## This is the BIZ I will write:", lBiz ## too much output lBiz contains the list of biz or the cat, while lABiz contains all biz of all cat! 
    lABiz += lBiz


##print("&&&&&&&&&&&&&& This is the list of ALL Businesses in each category:", lABiz)


print(" =============================== in getStates =======================================")

for i in range(0, len(lABiz)): 
    print("Main ############# i=", i, "len(lABiz):", len(lABiz))
    lSta = getStates(lABiz[i])
    lASta += lSta
    
##print("&&&&&&&&&&&&&& This is the list of ALL States in each business:", lASta)

## writing lASta into a file for debugging purposes!!!!
#f = open("./lASta2", "w")
f = open("./lASta2", "r", encoding="utf-8")
for i in range(0,len(lASta)):
    f.write(lASta[i]+",")

writeStoLfh()
#############

for i in range(0, len(lASta)): 
    lCit = getCities(lASta[i])
    lACit += lCit
    TGetLocation(lASta[i])

##print "#### writing lACit into a file for debugging purposes!!!!"
#f = open("./lACit2", "w")
f = open("./lACit2", "r", encoding="utf-8")

for i in range(0,len(lACit)):
    f.write(lACit[i]+",")

###f = "./lACit"
###lACit = open(f).read().split(",")
###print(len(lACit))

i=0
## print("@@@@@ lACit len is", len(lACit))
for i in range(0, len(lACit)): ## Here retrieve all stores that are present in cities
###for i in range(0, len(lACit)): ## TEST from 100 to 1000 occurrence, changed back from 0!
###    print("@@@@ I AM PROCESSING i=", i, "lACit=", lACit[i])
    TGetLocation(lACit[i]) 

print("&&&&&&&&&&&& This is the list of Cities in each State:", lACit) #too much display!!!

print ("Process of scrapping website ENDED at:", datetime.datetime.now())


##f.close()


# In[ ]:


########################## END OF MAIN CODE ###################################################
# Out:
# *** ./SAMPLE.csv  file DELETED ***
# top url is https://mystore411.com
# Process of scraping website STARTS at: 2020-09-03 23:55:33.805965
# ***  ./CID.csv  file DELETED ***
# ############# id antes de +10: 0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 000 ==
# ######### id after +10: 0
# ############# id antes de +10: 0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 000 ==
# ######### id after +10: 0
# ############# id antes de +10: 0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 000 ==
# ######### id after +10: 0
# ############# id antes de +10: 0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 000 ==
# ######### id after +10: 0
# ############# id antes de +10: 0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 000 ==
# ######### id after +10: 0
# ############# id antes de +10: 0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 000 ==
# ######### id after +10: 0
# ############# id antes de +10: 0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 000 ==
# ######### id after +10: 0
# ############# id antes de +10: 0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 000 ==
# ######### id after +10: 0
# ############# id antes de +10: 10
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 010 ==
# ######### id after +10: 10
# ############# id antes de +10: 20
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 020 ==
# ######### id after +10: 20
# ############# id antes de +10: 30
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 030 ==
# ######### id after +10: 30
# ############# id antes de +10: 40
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 040 ==
# ######### id after +10: 40
# ############# id antes de +10: 50
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 050 ==
# ######### id after +10: 50
# ############# id antes de +10: 60
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 060 ==
# ######### id after +10: 60
# ############# id antes de +10: 70
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 070 ==
# ######### id after +10: 70
# ############# id antes de +10: 80
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 080 ==
# ######### id after +10: 80
# ############# id antes de +10: 90
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 090 ==
# ######### id after +10: 90
# ############# id antes de +10: 100
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 100 ==
# ######### id after +10: 100
# ############# id antes de +10: 110
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 110 ==
# ######### id after +10: 110
# ############# id antes de +10: 120
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 120 ==
# ######### id after +10: 120
# ############# id antes de +10: 130
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 130 ==
# ######### id after +10: 130
# ############# id antes de +10: 140
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 140 ==
# ######### id after +10: 140
# ############# id antes de +10: 150
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 150 ==
# ######### id after +10: 150
# ############# id antes de +10: 160
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 160 ==
# ######### id after +10: 160
# ############# id antes de +10: 170
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 170 ==
# ######### id after +10: 170
# ############# id antes de +10: 180
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 180 ==
# ######### id after +10: 180
# ############# id antes de +10: 190
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 190 ==
# ######### id after +10: 190
# ############# id antes de +10: 200
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 200 ==
# ######### id after +10: 200
# ############# id antes de +10: 210
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 210 ==
# ######### id after +10: 210
# ############# id antes de +10: 220
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 220 ==
# ######### id after +10: 220
# ############# id antes de +10: 230
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 230 ==
# ######### id after +10: 230
# ############# id antes de +10: 240
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 240 ==
# ######### id after +10: 240
# ############# id antes de +10: 250
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 250 ==
# ######### id after +10: 250
# ############# id antes de +10: 260
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 260 ==
# ######### id after +10: 260
# ############# id antes de +10: 270
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 270 ==
# ######### id after +10: 270
# ############# id antes de +10: 280
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 280 ==
# ######### id after +10: 280
# ############# id antes de +10: 290
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 290 ==
# ######### id after +10: 290
# ############# id antes de +10: 300
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 300 ==
# ######### id after +10: 300
# ############# id antes de +10: 310
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 310 ==
# ######### id after +10: 310
# ############# id antes de +10: 320
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 320 ==
# ######### id after +10: 320
# ############# id antes de +10: 330
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 330 ==
# ######### id after +10: 330
# ############# id antes de +10: 340
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 340 ==
# ######### id after +10: 340
# ############# id antes de +10: 350
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 350 ==
# ######### id after +10: 350
# ############# id antes de +10: 360
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 360 ==
# ######### id after +10: 360
# ############# id antes de +10: 370
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 370 ==
# ######### id after +10: 370
# ############# id antes de +10: 380
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 380 ==
# ######### id after +10: 380
# ############# id antes de +10: 390
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 390 ==
# ######### id after +10: 390
# ############# id antes de +10: 400
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 400 ==
# ######### id after +10: 400
# ############# id antes de +10: 410
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 410 ==
# ######### id after +10: 410
# ############# id antes de +10: 420
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 420 ==
# ######### id after +10: 420
# ############# id antes de +10: 430
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 430 ==
# ######### id after +10: 430
# ############# id antes de +10: 440
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 440 ==
# ######### id after +10: 440
# ############# id antes de +10: 450
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 450 ==
# ######### id after +10: 450
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ############# id antes de +10: 460
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% x= 460 ==
# ######### id after +10: 460
# ***  ./BZC.csv  file DELETED ***
# lABiz is []
#  =============================== in getStates =======================================
# Main ############# i= 0 len(lABiz): 537
# ******************* in getStates def for URL: https://www.mystore411.com/store/listing/103/Canada/Mastercard-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/103/Alberta/Canada/Mastercard-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/103/British%20Columbia/Canada/Mastercard-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/103/Manitoba/Canada/Mastercard-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/103/New%20Brunswick/Canada/Mastercard-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/103/Newfoundland/Canada/Mastercard-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/103/Northwest%20Territories/Canada/Mastercard-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/103/Nova%20Scotia/Canada/Mastercard-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/103/Ontario/Canada/Mastercard-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/103/Prince%20Edward%20Island/Canada/Mastercard-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/103/Quebec/Canada/Mastercard-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/103/Saskatchewan/Canada/Mastercard-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/103/Yukon/Canada/Mastercard-ATM-store-locations
# Main ############# i= 1 len(lABiz): 537
# ******************* in getStates def for URL: https://www.mystore411.com/store/listing/92/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/Alberta/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/British%20Columbia/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/Manitoba/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/New%20Brunswick/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/Northwest%20Territories/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/Nova%20Scotia/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/Ontario/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/Prince%20Edward%20Island/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/Quebec/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/Saskatchewan/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/Yukon/Canada/Visa-ATM-store-locations
# Main ############# i= 2 len(lABiz): 537
# ******************* in getStates def for URL: https://www.mystore411.com/store/listing/220/Canada/Auto-Wares-Auto-Value-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/220/Alberta/Canada/Auto-Wares-Auto-Value-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/220/Manitoba/Canada/Auto-Wares-Auto-Value-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/220/New%20Brunswick/Canada/Auto-Wares-Auto-Value-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/220/Newfoundland/Canada/Auto-Wares-Auto-Value-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/220/Ontario/Canada/Auto-Wares-Auto-Value-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/220/Prince%20Edward%20Island/Canada/Auto-Wares-Auto-Value-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/220/Quebec/Canada/Auto-Wares-Auto-Value-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/220/Saskatchewan/Canada/Auto-Wares-Auto-Value-store-locations
# Main ############# i= 3 len(lABiz): 537
# ******************* in getStates def for URL: https://www.mystore411.com/store/listing/729/Canada/Bridgestone-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/729/Alberta/Canada/Bridgestone-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/729/British%20Columbia/Canada/Bridgestone-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/729/Manitoba/Canada/Bridgestone-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/729/New%20Brunswick/Canada/Bridgestone-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/729/Newfoundland/Canada/Bridgestone-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/729/Nova%20Scotia/Canada/Bridgestone-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/729/Ontario/Canada/Bridgestone-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/729/Prince%20Edward%20Island/Canada/Bridgestone-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/729/Quebec/Canada/Bridgestone-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/729/Saskatchewan/Canada/Bridgestone-store-locations
# Main ############# i= 4 len(lABiz): 537
# ******************* in getStates def for URL: https://www.mystore411.com/store/listing/2083/Canada/Carquest-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/2083/British%20Columbia/Canada/Carquest-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/2083/New%20Brunswick/Canada/Carquest-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/2083/Nova%20Scotia/Canada/Carquest-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/2083/Ontario/Canada/Carquest-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/2083/Prince%20Edward%20Island/Canada/Carquest-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/2083/Quebec/Canada/Carquest-store-locations
# Main ############# i= 5 len(lABiz): 537
# ******************* in getStates def for URL: https://www.mystore411.com/store/listing/765/Canada/Dunlop-Tires-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/765/Alberta/Canada/Dunlop-Tires-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/765/British%20Columbia/Canada/Dunlop-Tires-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/765/Manitoba/Canada/Dunlop-Tires-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/765/Michigan/Canada/Dunlop-Tires-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/765/New%20Brunswick/Canada/Dunlop-Tires-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/765/Newfoundland/Canada/Dunlop-Tires-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/765/Nova%20Scotia/Canada/Dunlop-Tires-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/765/Ontario/Canada/Dunlop-Tires-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/765/Prince%20Edward%20Island/Canada/Dunlop-Tires-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/765/Quebec/Canada/Dunlop-Tires-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/765/Saskatchewan/Canada/Dunlop-Tires-store-locations
# Main ############# i= 6 len(lABiz): 537
# ******************* in getStates def for URL: https://www.mystore411.com/store/listing/764/Canada/Michelin-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/764/Alberta/Canada/Michelin-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/764/British%20Columbia/Canada/Michelin-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/764/Manitoba/Canada/Michelin-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/764/New%20Brunswick/Canada/Michelin-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/764/Newfoundland/Canada/Michelin-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/764/Nova%20Scotia/Canada/Michelin-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/764/Ontario/Canada/Michelin-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/764/Prince%20Edward%20Island/Canada/Michelin-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/764/Quebec/Canada/Michelin-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/764/Saskatchewan/Canada/Michelin-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/764/Yukon/Canada/Michelin-store-locations
# Main ############# i= 7 len(lABiz): 537
# ******************* in getStates def for URL: https://www.mystore411.com/store/listing/2644/Canada/Monroe-Shocks-Struts-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/2644/Alberta/Canada/Monroe-Shocks-Struts-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/2644/British%20Columbia/Canada/Monroe-Shocks-Struts-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/2644/Manitoba/Canada/Monroe-Shocks-Struts-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/2644/New%20Brunswick/Canada/Monroe-Shocks-Struts-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/2644/Nova%20Scotia/Canada/Monroe-Shocks-Struts-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/2644/Ontario/Canada/Monroe-Shocks-Struts-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/2644/Quebec/Canada/Monroe-Shocks-Struts-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/2644/Saskatchewan/Canada/Monroe-Shocks-Struts-store-locations
# Main ############# i= 8 len(lABiz): 537
# ******************* in getStates def for URL: https://www.mystore411.com/store/listing/196/Canada/NAPA-Auto-Center-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/196/Alberta/Canada/NAPA-Auto-Center-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/196/British%20Columbia/Canada/NAPA-Auto-Center-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/196/Manitoba/Canada/NAPA-Auto-Center-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/196/New%20Brunswick/Canada/NAPA-Auto-Center-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/196/Nova%20Scotia/Canada/NAPA-Auto-Center-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/196/Ontario/Canada/NAPA-Auto-Center-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/196/Prince%20Edward%20Island/Canada/NAPA-Auto-Center-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/196/Quebec/Canada/NAPA-Auto-Center-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/196/Saskatchewan/Canada/NAPA-Auto-Center-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/196/Yukon/Canada/NAPA-Auto-Center-store-locations
# Main ############# i= 9 len(lABiz): 537
# ******************* in getStates def for URL: https://www.mystore411.com/store/listing/1334/Canada/Saris-Racks-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/1334/Alberta/Canada/Saris-Racks-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/1334/British%20Columbia/Canada/Saris-Racks-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/1334/Manitoba/Canada/Saris-Racks-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/1334/New%20Brunswick/Canada/Saris-Racks-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/1334/Nova%20Scotia/Canada/Saris-Racks-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/1334/Ontario/Canada/Saris-Racks-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/1334/Prince%20Edward%20Island/Canada/Saris-Racks-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/1334/Quebec/Canada/Saris-Racks-store-locations
# Main ############# i= 10 len(lABiz): 537
# ******************* in getStates def for URL: https://www.mystore411.com/store/listing/502/Canada/State-Farm-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/502/Alberta/Canada/State-Farm-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/502/New%20Brunswick/Canada/State-Farm-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/502/Ontario/Canada/State-Farm-store-locations
# Main ############# i= 11 len(lABiz): 537
# ******************* in getStates def for URL: https://www.mystore411.com/store/listing/92/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/Alberta/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/British%20Columbia/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/Manitoba/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/New%20Brunswick/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/Northwest%20Territories/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/Nova%20Scotia/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/Ontario/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/Prince%20Edward%20Island/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/Quebec/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/Saskatchewan/Canada/Visa-ATM-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/92/Yukon/Canada/Visa-ATM-store-locations
# Main ############# i= 12 len(lABiz): 537
# ******************* in getStates def for URL: https://www.mystore411.com/store/listing/455/Canada/Biore-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/455/Alberta/Canada/Biore-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/455/British%20Columbia/Canada/Biore-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/455/Manitoba/Canada/Biore-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/455/New%20Brunswick/Canada/Biore-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/455/Newfoundland/Canada/Biore-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/455/Nova%20Scotia/Canada/Biore-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/455/Ontario/Canada/Biore-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/455/Prince%20Edward%20Island/Canada/Biore-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/455/Quebec/Canada/Biore-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/455/Saskatchewan/Canada/Biore-store-locations
# Main ############# i= 13 len(lABiz): 537
# ******************* in getStates def for URL: https://www.mystore411.com/store/listing/10009/Canada/Cosmetics-Beauty-store-locations
# ************** THERE is NO COLSPAN=4 for  https://www.mystore411.com/store/listing/10009/Canada/Cosmetics-Beauty-store-locations *****************************
# ************** I will GetLocation (url) ***************************************
# at TGetLocation with url: https://www.mystore411.com/store/listing/10009/Canada/Cosmetics-Beauty-store-locations
# AFTER READING URL. url for top biz is https://www.mystore411.com/store/listing/10009/Canada/Cosmetics-Beauty-store-locations
# at TgetLocation ====== url for top biz is https://www.mystore411.com/store/listing/10009/Canada/Cosmetics-Beauty-store-locations
# a[href] with (view) ====>>>>>>> /store/view/25103811/Canada/Cosmetics,-Beauty-Calgary
# counter =  1
# BEFORE ====== storeURL is: https://mystore411.com/store/view/25103811/Canada/Cosmetics%2C-Beauty-Calgary a[href] is: /store/view/25103811/Canada/Cosmetics,-Beauty-Calgary
# at getAddress ====== address is> 102 8th Ave SW <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Alberta
# The address of the biz is: 102 8th Ave SW Calgary Alberta T2P 1B5
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/25055079/Canada/Cosmetics,-Beauty-Calgary
# counter =  2
# BEFORE ====== storeURL is: https://mystore411.com/store/view/25055079/Canada/Cosmetics%2C-Beauty-Calgary a[href] is: /store/view/25055079/Canada/Cosmetics,-Beauty-Calgary
# at getAddress ====== address is> 4307 130 Ave SE #74 <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Alberta
# The address of the biz is: 4307 130 Ave SE #74 Calgary Alberta T2Z 3V8
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/1112546420/Canada/Cosmetics,-Beauty-Edmonton
# counter =  3
# BEFORE ====== storeURL is: https://mystore411.com/store/view/1112546420/Canada/Cosmetics%2C-Beauty-Edmonton a[href] is: /store/view/1112546420/Canada/Cosmetics,-Beauty-Edmonton
# at getAddress ====== address is> 6012 82 Avenue Northwest <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Alberta
# The address of the biz is: 6012 82 Avenue Northwest Edmonton Alberta T6B 0E7
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/25052457/Canada/Cosmetics,-Beauty-Edmonton
# counter =  4
# BEFORE ====== storeURL is: https://mystore411.com/store/view/25052457/Canada/Cosmetics%2C-Beauty-Edmonton a[href] is: /store/view/25052457/Canada/Cosmetics,-Beauty-Edmonton
# at getAddress ====== address is> 9134 23 Ave <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Alberta
# The address of the biz is: 9134 23 Ave Edmonton Alberta T6N 1H9
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/1112456264/Canada/Cosmetics,-Beauty-Edmonton
# counter =  5
# BEFORE ====== storeURL is: https://mystore411.com/store/view/1112456264/Canada/Cosmetics%2C-Beauty-Edmonton a[href] is: /store/view/1112456264/Canada/Cosmetics,-Beauty-Edmonton
# at getAddress ====== address is> 18927 81a Avenue NW <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Alberta
# The address of the biz is: 18927 81a Avenue NW Edmonton Alberta T5T 5C3
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/1112347584/Canada/Cosmetics,-Beauty-Abbotsford
# counter =  6
# BEFORE ====== storeURL is: https://mystore411.com/store/view/1112347584/Canada/Cosmetics%2C-Beauty-Abbotsford a[href] is: /store/view/1112347584/Canada/Cosmetics,-Beauty-Abbotsford
# at getAddress ====== address is> 1975 McCallum Rd <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= British Columbia
# The address of the biz is: 1975 McCallum Rd Abbotsford British Columbia V2S 3N3
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/112411781/Canada/Cosmetics,-Beauty-Port-Moody
# counter =  7
# BEFORE ====== storeURL is: https://mystore411.com/store/view/112411781/Canada/Cosmetics%2C-Beauty-Port-Moody a[href] is: /store/view/112411781/Canada/Cosmetics,-Beauty-Port-Moody
# at getAddress ====== address is> 775 Appleyard Court <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= British Columbia
# The address of the biz is: 775 Appleyard Court Port Moody British Columbia V3H 3X1
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/1112627405/Canada/Cosmetics,-Beauty-Surrey
# counter =  8
# BEFORE ====== storeURL is: https://mystore411.com/store/view/1112627405/Canada/Cosmetics%2C-Beauty-Surrey a[href] is: /store/view/1112627405/Canada/Cosmetics,-Beauty-Surrey
# at getAddress ====== address is> 8056 King George Blvd <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= British Columbia
# The address of the biz is: 8056 King George Blvd Surrey British Columbia V3W 5B5
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/25060354/Canada/Cosmetics,-Beauty-Vancouver
# counter =  9
# BEFORE ====== storeURL is: https://mystore411.com/store/view/25060354/Canada/Cosmetics%2C-Beauty-Vancouver a[href] is: /store/view/25060354/Canada/Cosmetics,-Beauty-Vancouver
# at getAddress ====== address is> 955 Hornby St <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= British Columbia
# The address of the biz is: 955 Hornby St Vancouver British Columbia V6Z 1V3
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/24908475/Canada/Cosmetics,-Beauty-Winfield
# counter =  10
# BEFORE ====== storeURL is: https://mystore411.com/store/view/24908475/Canada/Cosmetics%2C-Beauty-Winfield a[href] is: /store/view/24908475/Canada/Cosmetics,-Beauty-Winfield
# at getAddress ====== address is> 10836 Sherman Drive <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= British Columbia
# The address of the biz is: 10836 Sherman Drive Winfield British Columbia V4V 1W8
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/1112798496/Canada/Cosmetics,-Beauty-Winnipeg
# counter =  11
# BEFORE ====== storeURL is: https://mystore411.com/store/view/1112798496/Canada/Cosmetics%2C-Beauty-Winnipeg a[href] is: /store/view/1112798496/Canada/Cosmetics,-Beauty-Winnipeg
# at getAddress ====== address is> 1395 Ellice Ave <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Manitoba
# The address of the biz is: 1395 Ellice Ave Winnipeg Manitoba R3G 3P2
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/24998320/Canada/Cosmetics,-Beauty-Angus
# counter =  12
# BEFORE ====== storeURL is: https://mystore411.com/store/view/24998320/Canada/Cosmetics%2C-Beauty-Angus a[href] is: /store/view/24998320/Canada/Cosmetics,-Beauty-Angus
# at getAddress ====== address is> 7 Commerce Road <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 7 Commerce Road Angus Ontario L0M 1B2
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/1112886946/Canada/Cosmetics,-Beauty-Nepean
# counter =  13
# BEFORE ====== storeURL is: https://mystore411.com/store/view/1112886946/Canada/Cosmetics%2C-Beauty-Nepean a[href] is: /store/view/1112886946/Canada/Cosmetics,-Beauty-Nepean
# at getAddress ====== address is> 71 Marketplace Ave <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 71 Marketplace Ave Nepean Ontario K2J 5G4
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/25001105/Canada/Cosmetics,-Beauty-Orangeville
# counter =  14
# BEFORE ====== storeURL is: https://mystore411.com/store/view/25001105/Canada/Cosmetics%2C-Beauty-Orangeville a[href] is: /store/view/25001105/Canada/Cosmetics,-Beauty-Orangeville
# at getAddress ====== address is> 65 Broadway <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 65 Broadway Orangeville Ontario L9W 1J4
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/112347797/Canada/Cosmetics,-Beauty-Sudbury
# counter =  15
# BEFORE ====== storeURL is: https://mystore411.com/store/view/112347797/Canada/Cosmetics%2C-Beauty-Sudbury a[href] is: /store/view/112347797/Canada/Cosmetics,-Beauty-Sudbury
# at getAddress ====== address is> 900 Lasalle Boulevard <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 900 Lasalle Boulevard Sudbury Ontario
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/1112797608/Canada/Cosmetics,-Beauty-Thornhill
# counter =  16
# BEFORE ====== storeURL is: https://mystore411.com/store/view/1112797608/Canada/Cosmetics%2C-Beauty-Thornhill a[href] is: /store/view/1112797608/Canada/Cosmetics,-Beauty-Thornhill
# at getAddress ====== address is> 708 – 7905 Bayview Ave. <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 708 – 7905 Bayview Ave. Thornhill Ontario L3T 7N3
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/25105028/Canada/Cosmetics,-Beauty-Toronto
# counter =  17
# BEFORE ====== storeURL is: https://mystore411.com/store/view/25105028/Canada/Cosmetics%2C-Beauty-Toronto a[href] is: /store/view/25105028/Canada/Cosmetics,-Beauty-Toronto
# at getAddress ====== address is> 1 Eglinton Ave East <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 1 Eglinton Ave East Toronto Ontario M4P 3A1
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/25103441/Canada/Cosmetics,-Beauty-Toronto
# counter =  18
# BEFORE ====== storeURL is: https://mystore411.com/store/view/25103441/Canada/Cosmetics%2C-Beauty-Toronto a[href] is: /store/view/25103441/Canada/Cosmetics,-Beauty-Toronto
# at getAddress ====== address is> 3024 Dundas Street West <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 3024 Dundas Street West Toronto Ontario M6P 1Z3
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/1112353534/Canada/Cosmetics,-Beauty-Montreal
# counter =  19
# BEFORE ====== storeURL is: https://mystore411.com/store/view/1112353534/Canada/Cosmetics%2C-Beauty-Montreal a[href] is: /store/view/1112353534/Canada/Cosmetics,-Beauty-Montreal
# at getAddress ====== address is> 4060 Rue Sainte-Catherine O. <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Quebec
# The address of the biz is: 4060 Rue Sainte-Catherine O. Montreal Quebec H3Z 2Z3
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# Main ############# i= 14 len(lABiz): 537
# ******************* in getStates def for URL: https://www.mystore411.com/store/listing/2010/Canada/Crabtree-Evelyn-store-locations
# ************** THERE is NO COLSPAN=4 for  https://www.mystore411.com/store/listing/2010/Canada/Crabtree-Evelyn-store-locations *****************************
# ************** I will GetLocation (url) ***************************************
# at TGetLocation with url: https://www.mystore411.com/store/listing/2010/Canada/Crabtree-Evelyn-store-locations
# AFTER READING URL. url for top biz is https://www.mystore411.com/store/listing/2010/Canada/Crabtree-Evelyn-store-locations
# at TgetLocation ====== url for top biz is https://www.mystore411.com/store/listing/2010/Canada/Crabtree-Evelyn-store-locations
# a[href] with (view) ====>>>>>>> /store/view/10785014/Canada/Crabtree-&-Evelyn-Calgary
# counter =  1
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10785014/Canada/Crabtree-%26-Evelyn-Calgary a[href] is: /store/view/10785014/Canada/Crabtree-&-Evelyn-Calgary
# at getAddress ====== address is> 3625 Shaganappi Tr. N. W. <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Alberta
# The address of the biz is: 3625 Shaganappi Tr. N. W. Calgary Alberta T3A 0E2
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10785104/Canada/Crabtree-&-Evelyn-Edmonton
# counter =  2
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10785104/Canada/Crabtree-%26-Evelyn-Edmonton a[href] is: /store/view/10785104/Canada/Crabtree-&-Evelyn-Edmonton
# at getAddress ====== address is> 11100-51st Ave.  Unit 13A <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Alberta
# The address of the biz is: 11100-51st Ave.  Unit 13A Edmonton Alberta T6H 4M6
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10785105/Canada/Crabtree-&-Evelyn-Edmonton
# counter =  3
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10785105/Canada/Crabtree-%26-Evelyn-Edmonton a[href] is: /store/view/10785105/Canada/Crabtree-&-Evelyn-Edmonton
# at getAddress ====== address is> 8882-170 Street Suite 2890 <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Alberta
# The address of the biz is: 8882-170 Street Suite 2890 Edmonton Alberta T5T 3J7
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10785072/Canada/Crabtree-&-Evelyn-Burnaby
# counter =  4
# ...
# counter =  18
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10424491/Canada/Eddie-Bauer-St.-Johns a[href] is: /store/view/10424491/Canada/Eddie-Bauer-St.-Johns
# at getAddress ====== address is> 48 Kenmount Road   29 <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Newfoundland
# The address of the biz is: 48 Kenmount Road   29 St. Johns Newfoundland A1B 1W3
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10424489/Canada/Eddie-Bauer-Dartmouth
# counter =  19
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10424489/Canada/Eddie-Bauer-Dartmouth a[href] is: /store/view/10424489/Canada/Eddie-Bauer-Dartmouth
# at getAddress ====== address is> 21 Mic Mac Boulevard   295 <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Nova Scotia
# The address of the biz is: 21 Mic Mac Boulevard   295 Dartmouth Nova Scotia B3A 4K7
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10424485/Canada/Eddie-Bauer-Belleville
# counter =  20
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10424485/Canada/Eddie-Bauer-Belleville a[href] is: /store/view/10424485/Canada/Eddie-Bauer-Belleville
# at getAddress ====== address is> 390 North Front Street   D11 <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 390 North Front Street   D11 Belleville Ontario K8P 3E1
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10424463/Canada/Eddie-Bauer-Etobicoke
# counter =  21
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10424463/Canada/Eddie-Bauer-Etobicoke a[href] is: /store/view/10424463/Canada/Eddie-Bauer-Etobicoke
# at getAddress ====== address is> 25 The West Mall   78 <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 25 The West Mall   78 Etobicoke Ontario M9C 1B8
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10424464/Canada/Eddie-Bauer-Hamilton
# counter =  22
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10424464/Canada/Eddie-Bauer-Hamilton a[href] is: /store/view/10424464/Canada/Eddie-Bauer-Hamilton
# at getAddress ====== address is> 999 Upper Wentworth Street   411 <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 999 Upper Wentworth Street   411 Hamilton Ontario L9A 4X5
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10424458/Canada/Eddie-Bauer-Markham
# counter =  23
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10424458/Canada/Eddie-Bauer-Markham a[href] is: /store/view/10424458/Canada/Eddie-Bauer-Markham
# at getAddress ====== address is> 438-5000 Highway 7 <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 438-5000 Highway 7 Markham Ontario L3R 4M9
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10424462/Canada/Eddie-Bauer-Mississauga
# counter =  24
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10424462/Canada/Eddie-Bauer-Mississauga a[href] is: /store/view/10424462/Canada/Eddie-Bauer-Mississauga
# at getAddress ====== address is> 100 City Centre Dr <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 100 City Centre Dr Mississauga Ontario L5B 2C9
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10424486/Canada/Eddie-Bauer-Nepean
# counter =  25
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10424486/Canada/Eddie-Bauer-Nepean a[href] is: /store/view/10424486/Canada/Eddie-Bauer-Nepean
# at getAddress ====== address is> 100 Bayshore Drive <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 100 Bayshore Drive Nepean Ontario K2B 8C1
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10424484/Canada/Eddie-Bauer-Newmarket
# counter =  26
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10424484/Canada/Eddie-Bauer-Newmarket a[href] is: /store/view/10424484/Canada/Eddie-Bauer-Newmarket
# at getAddress ====== address is> 17600 Yonge Street   DD12 <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 17600 Yonge Street   DD12 Newmarket Ontario L3Y 4Z1
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10424461/Canada/Eddie-Bauer-North-York
# counter =  27
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10424461/Canada/Eddie-Bauer-North-York a[href] is: /store/view/10424461/Canada/Eddie-Bauer-North-York
# at getAddress ====== address is> 32 Karl Fraser Road    CRU J10 <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 32 Karl Fraser Road    CRU J10 North York Ontario M3C 0E8
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10424488/Canada/Eddie-Bauer-Orleans
# counter =  28
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10424488/Canada/Eddie-Bauer-Orleans a[href] is: /store/view/10424488/Canada/Eddie-Bauer-Orleans
# at getAddress ====== address is> 1101 Place D'Orleans Drive    700 <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 1101 Place D'Orleans Drive    700 Orleans Ontario K1C 2L9
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10424459/Canada/Eddie-Bauer-Oshawa
# counter =  29
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10424459/Canada/Eddie-Bauer-Oshawa a[href] is: /store/view/10424459/Canada/Eddie-Bauer-Oshawa
# at getAddress ====== address is> 419 King Street West <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 419 King Street West Oshawa Ontario L1J 2K5
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10424487/Canada/Eddie-Bauer-Ottawa
# counter =  30
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10424487/Canada/Eddie-Bauer-Ottawa a[href] is: /store/view/10424487/Canada/Eddie-Bauer-Ottawa
# at getAddress ====== address is> 50 Rideau   308 <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 50 Rideau   308 Ottawa Ontario K1N 9J7
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10424465/Canada/Eddie-Bauer-Toronto
# counter =  31
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10424465/Canada/Eddie-Bauer-Toronto a[href] is: /store/view/10424465/Canada/Eddie-Bauer-Toronto
# at getAddress ====== address is> 220 Yonge Street  A046B <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 220 Yonge Street  A046B Toronto Ontario M5B 2H6
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10424460/Canada/Eddie-Bauer-Toronto
# counter =  32
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10424460/Canada/Eddie-Bauer-Toronto a[href] is: /store/view/10424460/Canada/Eddie-Bauer-Toronto
# at getAddress ====== address is> 1 Yorkdale Rd.   158 <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 1 Yorkdale Rd.   158 Toronto Ontario M6A 3A1
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10424457/Canada/Eddie-Bauer-Willowdale
# counter =  33
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10424457/Canada/Eddie-Bauer-Willowdale a[href] is: /store/view/10424457/Canada/Eddie-Bauer-Willowdale
# at getAddress ====== address is> 1800 Sheppard Ave. E.   1012 <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Ontario
# The address of the biz is: 1800 Sheppard Ave. E.   1012 Willowdale Ontario M2J 5A7
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10424480/Canada/Eddie-Bauer-Regina
# counter =  34
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10424480/Canada/Eddie-Bauer-Regina a[href] is: /store/view/10424480/Canada/Eddie-Bauer-Regina
# at getAddress ====== address is> 2102 11th Ave.    TT8A <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Saskatchewan
# The address of the biz is: 2102 11th Ave.    TT8A Regina Saskatchewan S4P 3Y6
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10424479/Canada/Eddie-Bauer-Saskatoon
# counter =  35
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10424479/Canada/Eddie-Bauer-Saskatoon a[href] is: /store/view/10424479/Canada/Eddie-Bauer-Saskatoon
# at getAddress ====== address is> 201 First Avenue S. <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Saskatchewan
# The address of the biz is: 201 First Avenue S. Saskatoon Saskatchewan S7K 1J5
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# Main ############# i= 352 len(lABiz): 537
# ******************* in getStates def for URL: https://www.mystore411.com/store/listing/1325/Canada/Elan-Skis-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/1325/Alberta/Canada/Elan-Skis-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/1325/British%20Columbia/Canada/Elan-Skis-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/1325/Ontario/Canada/Elan-Skis-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/1325/Quebec/Canada/Elan-Skis-store-locations
# Main ############# i= 353 len(lABiz): 537
# ******************* in getStates def for URL: https://www.mystore411.com/store/listing/442/Canada/Electric-Sunglass-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/442/Alberta/Canada/Electric-Sunglass-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/442/British%20Columbia/Canada/Electric-Sunglass-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/442/California/Canada/Electric-Sunglass-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/442/Manitoba/Canada/Electric-Sunglass-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/442/New%20Brunswick/Canada/Electric-Sunglass-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/442/Ontario/Canada/Electric-Sunglass-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/442/Prince%20Edward%20Island/Canada/Electric-Sunglass-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/442/Quebec/Canada/Electric-Sunglass-store-locations
# url of biz found is: https://www.mystore411.com/store/list_state/442/Saskatchewan/Canada/Electric-Sunglass-store-locations
# Main ############# i= 354 len(lABiz): 537
# ******************* in getStates def for URL: https://www.mystore411.com/store/listing/874/Canada/Eureka-store-locations
# ************** THERE is NO COLSPAN=4 for  https://www.mystore411.com/store/listing/874/Canada/Eureka-store-locations *****************************
# ************** I will GetLocation (url) ***************************************
# at TGetLocation with url: https://www.mystore411.com/store/listing/874/Canada/Eureka-store-locations
# AFTER READING URL. url for top biz is https://www.mystore411.com/store/listing/874/Canada/Eureka-store-locations
# at TgetLocation ====== url for top biz is https://www.mystore411.com/store/listing/874/Canada/Eureka-store-locations
# a[href] with (view) ====>>>>>>> /store/view/10947123/Canada/Eureka-Edmonton
# counter =  1
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10947123/Canada/Eureka-Edmonton a[href] is: /store/view/10947123/Canada/Eureka-Edmonton
# at getAddress ====== address is> 14205-109th Avenue <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Alberta
# The address of the biz is: 14205-109th Avenue Edmonton Alberta
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10946963/Canada/Eureka-Medicine-Hat
# counter =  2
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10946963/Canada/Eureka-Medicine-Hat a[href] is: /store/view/10946963/Canada/Eureka-Medicine-Hat
# at getAddress ====== address is> 1023 Allowance Avenue S.e. <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= Alberta
# The address of the biz is: 1023 Allowance Avenue S.e. Medicine Hat Alberta
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10947130/Canada/Eureka-Kelowna
# counter =  3
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10947130/Canada/Eureka-Kelowna a[href] is: /store/view/10947130/Canada/Eureka-Kelowna
# at getAddress ====== address is> 160 Dougall Road <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= British Columbia
# The address of the biz is: 160 Dougall Road Kelowna British Columbia
# lat and long are: None   None
# ********* ERROR when trying to get the place_id Google API didn't like it! **********
# a[href] with (view) ====>>>>>>> /store/view/10946961/Canada/Eureka-Surrey
# counter =  4
# BEFORE ====== storeURL is: https://mystore411.com/store/view/10946961/Canada/Eureka-Surrey a[href] is: /store/view/10946961/Canada/Eureka-Surrey
# at getAddress ====== address is> 101  <
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&**&*&*&* OutProv= British Columbia
# The address of the biz is: 101  Surrey British Columbia
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-09b37cd92eca> in <module>
#      73 for i in range(0, len(lABiz)):
#      74     print("Main ############# i=", i, "len(lABiz):", len(lABiz))
# ---> 75     lSta = getStates(lABiz[i])
#      76     lASta += lSta
#      77
#
# <ipython-input-12-2640796b2e26> in getStates(url)
#      38         print("************** THERE is NO COLSPAN=4 for ", url, "*****************************")
#      39         print("************** I will GetLocation (url) ***************************************")
# ---> 40         TGetLocation(url)
#      41
#      42     return lStates
#
# <ipython-input-13-1f78bb32d5cf> in TGetLocation(url)
#      59                 ##ll = getGeoloc(add).encode('ascii', 'ignore') ## 5625 Boul. M\xe9tropolitain St-L\xe9onard Quebec H1P 1X3  This may not be working
#      60
# ---> 61                 lat, lng = getGeoloc(add) ## Query Google API
#      62
#      63
#
# ValueError: not enough values to unpack (expected 2, got 0)
